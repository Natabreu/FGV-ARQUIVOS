# %% [markdown]
# <a href="https://colab.research.google.com/github/Natabreu/FGV-ARQUIVOS/blob/main/Teste_Nat_Abreu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello There!")
# Out:
# Hello There!

# %%
# !pip install scikit-learn

# %%
from sklearn.datasets import load_boston
Boston = load_boston ()
print(Boston.data.shape)
# Out:
# (506, 13)

# %%
with open("Colors.txt",'r')as open_file:
  print('Colors.txt content:\n'+ open_file.read())
# Out:
# Colors.txt content:
# Color          Value
# Red            1
# Orange         2
# Yellow         3
# Green          4
# Blue           5
# Purple         6
# Black          7
# White          8

# %%
  import matplotlib.image as img
  import matplotlib.pyplot as plt
  # %matplotlib inline
  image = img.imread("Colorblk.jpg")
  print (image.shape)
  print (image.size)
  plt.imshow (image)
  plt.show ()
# Out:
# (619, 990, 3)
# 1838430

# %%
n=3
with open("Colors.txt",'r')as open_file:
  for j, observation in enumerate(open_file):
    if j % n==0:
      print ("Reading Line: " + str(j) + "Content: " + observation)
# Out:
# Reading Line: 0Content: Color          Value
#
# Reading Line: 3Content: Yellow         3
#
# Reading Line: 6Content: Purple         6
#
# Reading Line: 9Content:

# %%
import pandas as pd
color_table = pd.io.parsers.read_table("Colors.txt")
print(color_table)
# Out:
#   Color          Value
# 0     Red            1
# 1     Orange         2
# 2     Yellow         3
# 3     Green          4
# 4     Blue           5
# 5     Purple         6
# 6     Black          7
# 7     White          8

# %%
import pandas as pd
titanic = pd.io.parsers.read_csv("titanic.csv")
x = titanic [["Age"]]
print(x)
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
x = titanic [["Age"]].values
print(x)
# Out:
# [[22.  ]
#  [38.  ]
#  [26.  ]
#  [35.  ]
#  [35.  ]
#  [  nan]
#  [54.  ]
#  [ 2.  ]
#  [27.  ]
#  [14.  ]
#  [ 4.  ]
#  [58.  ]
#  [20.  ]
#  [39.  ]
#  [14.  ]
#  [55.  ]
#  [ 2.  ]
#  [  nan]
#  [31.  ]
#  [  nan]
#  [35.  ]
#  [34.  ]
#  [15.  ]
#  [28.  ]
#  [ 8.  ]
#  [38.  ]
#  [  nan]
#  [19.  ]
#  [  nan]
#  [  nan]
#  [40.  ]
#  [  nan]
#  [  nan]
#  [66.  ]
#  [28.  ]
#  [42.  ]
#  [  nan]
#  [21.  ]
#  [18.  ]
#  [14.  ]
#  [40.  ]
#  [27.  ]
#  [  nan]
#  [ 3.  ]
#  [19.  ]
#  [  nan]
#  [  nan]
#  [  nan]
#  [  nan]
#  [18.  ]
#  [ 7.  ]
#  [21.  ]
#  [49.  ]
#  [29.  ]
#  [65.  ]
#  [  nan]
#  [21.  ]
#  [28.5 ]
#  [ 5.  ]
#  [11.  ]
#  [22.  ]
#  [38.  ]
#  [45.  ]
#  [ 4.  ]
#  [  nan]
#  [  nan]
#  [29.  ]
#  [19.  ]
#  [17.  ]
#  [26.  ]
#  [32.  ]
#  [16.  ]
#  [21.  ]
#  [26.  ]
#  [32.  ]
#  [25.  ]
#  [  nan]
#  [  nan]
#  [ 0.83]
#  [30.  ]
#  [22.  ]
#  [29.  ]
#  [  nan]
#  [28.  ]
#  [17.  ]
#  [33.  ]
#  [16.  ]
#  [  nan]
#  [23.  ]
#  [24.  ]
# ...

# %%
import pandas as pd
xlsx = pd.ExcelFile("encontro.xlsx")
trig_values = xlsx.parse("Planilha1", index_col=None, 
                         na_values=['NA'])
print(trig_values)
# Out:
#      programa data de exibição    anunciante  ...   11   12 Unnamed: 43
# 0    Encontro       2020-01-27         Ifood  ...  0.0  0.0         0.0
# 1    Encontro       2020-01-31         Ifood  ...  0.0  0.0        78.0
# 2    Encontro       2020-02-04     Brilhante  ...  0.0  0.0         0.0
# 3    Encontro       2020-02-11     PagSeguro  ...  0.0  0.0         0.0
# 4    Encontro       2020-02-14  Oticas Carol  ...  0.0  0.0        78.0
# ..        ...              ...           ...  ...  ...  ...         ...
# 293       NaN              NaT           NaN  ...  NaN  NaN         NaN
# 294       NaN              NaT           NaN  ...  NaN  NaN         NaN
# 295       NaN              NaT           NaN  ...  NaN  NaN         NaN
# 296       NaN              NaT           NaN  ...  NaN  NaN         NaN
# 297       NaN              NaT             0  ...  NaN  NaN         NaN
#
# [298 rows x 44 columns]

# %%
import pandas as pd
pd.set_option ("display.width",55)
df = pd.DataFrame ({'A': [0,0,0,0,0,1,1],
                    'B': [1,2,3,5,4,2,5],
                    'C': [5,3,4,1,1,2,3]})
a_group_desc = df.groupby('A').describe()
print(a_group_desc)
stacked = a_group_desc.stack()
print(stacked)
# Out:
#       B                                 ...         C
#   count mean       std  min   25%  50%  ...       std  min   25%  50%   75%  max
# A                                       ...
# 0   5.0  3.0  1.581139  1.0  2.00  3.0  ...  1.788854  1.0  1.00  3.0  4.00  5.0
# 1   2.0  3.5  2.121320  2.0  2.75  3.5  ...  0.707107  2.0  2.25  2.5  2.75  3.0
#
# [2 rows x 16 columns]
#                 B         C
# A
# 0 count  5.000000  5.000000
#   mean   3.000000  2.800000
#   std    1.581139  1.788854
#   min    1.000000  1.000000
#   25%    2.000000  1.000000
#   50%    3.000000  3.000000
#   75%    4.000000  4.000000
#   max    5.000000  5.000000
# 1 count  2.000000  2.000000
#   mean   3.500000  2.500000
#   std    2.121320  0.707107
#   min    2.000000  2.000000
#   25%    2.750000  2.250000
#   50%    3.500000  2.500000
#   75%    4.250000  2.750000
#   max    5.000000  3.000000

# %%
import pandas as pd
car_colors = pd.Series (['Blue', 'Red', 'Green'], dtype = 'category')
car_data = pd.Series (pd.Categorical(['Yellow','Green','Red','Blue', 'Purple'],categories=car_colors, ordered=False))
find_entries = pd.isnull (car_data)
print(car_colors)
print()
print(car_data)
print()
print(find_entries[find_entries == True])
# Out:
# 0     Blue
# 1      Red
# 2    Green
# dtype: category
# Categories (3, object): ['Blue', 'Green', 'Red']
#
# 0      NaN
# 1    Green
# 2      Red
# 3     Blue
# 4      NaN
# dtype: category
# Categories (3, object): ['Blue', 'Green', 'Red']
#
# 0    True
# 4    True
# dtype: bool
